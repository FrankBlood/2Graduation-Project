# %%
#-*- coding:utf-8 -*-

# %%
import graphlab
import re
import pandas as pd
import string
import jieba.posseg as pseg
import jieba
from pyltp import Segmentor, Postagger, Parser

# %%
segmentor = Segmentor()
postagger = Postagger()
parser = Parser()
segmentor.load('E:/Python/pyltp/ltp_data/cws.model')
postagger.load('E:/Python/pyltp/ltp_data/pos.model')
parser.load('E:/Python/pyltp/ltp_data/parser.model')

# %%
data = graphlab.SFrame.read_csv('Sogou50W.csv', delimiter=',', header=True, column_type_hints=[str, str, str, str, str])
# Out:
# This non-commercial license of GraphLab Create is assigned to guoxiuhe@nefu.edu.cn and will expire on April 02, 2017. For commercial licensing options, visit https://dato.com/buy/.
# 2016-05-17 17:02:44,463 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: C:\Users\heguoxiu\AppData\Local\Temp\graphlab_server_1463475747.log.0
# Finished parsing file E:\Python\2Graduation-Project\Sogou50W.csv
# Parsing completed. Parsed 500733 lines in 1.6831 secs.

# %%
data.head()
# Out:
# Columns:
# 	﻿time	str
# 	user_id	str
# 	query	str
# 	result_click	str
# 	url	str
#
# Rows: 10
#
# Data:
# +----------+-------------------+---------------------------+--------------+
# |  ﻿time   |      user_id      |           query           | result_click |
# +----------+-------------------+---------------------------+--------------+
# | 00:00:00 |  3933365481995287 |      ["最佳受孕时间"]     |     6 3      |
# | 00:00:00 |  8248403977107859 |          ["pdf"]          |     1 1      |
# | 00:00:00 |  6551182914925117 |      ["尼康相机报价"]     |     6 4      |
# | 00:00:00 |  6478452674857782 |           [1000]          |     4 1      |
# | 00:00:00 | 23457845712802688 |          ["人妖"]         |     4 1      |
# | 00:00:00 |  4625224675315291 | ["印尼排华是怎么回事"]... |     2 6      |
# | 00:00:00 |  5750662932822584 |     ["女士找鸭子经历"]    |     3 2      |
# | 00:00:01 |  8761939261737872 |     ["年轻人住房问题"]    |     11 7     |
# | 00:00:01 |  866575159856572  | ["印尼排华是怎么回事"]... |     8 2      |
# | 00:00:01 |  5388089767668996 |     ["免费看三级图片"]    |     9 7      |
# +----------+-------------------+---------------------------+--------------+
# +-------------------------------+
# |              url              |
# +-------------------------------+
# | ks.cn.yahoo.com/question/1... |
# | download.it168.com/18/1805... |
# | product.it168.com/list/b/0... |
# |         www.1000dy.cn/        |
# | play.zol.com.cn/detail/165... |
# | zhidao.baidu.com/question/... |
# | zhangxiaoyu52.blog.sohu.co... |
# | news.qq.com/a/20070810/002... |
# | wenwen.soso.com/z/q3884674... |
# | 226500.cn/bbs/dispbbs.asp?... |
# +-------------------------------+
# [10 rows x 5 columns]

# %%
data['result_and_click'] = data['result_click'].apply(lambda x : re.split(r'\s+',x))

# %%
def getfirst(l):
    return int(l[0])
def getsecond(l):
    return int(l[1])

data['result_rank'] = data['result_and_click'].apply(lambda l: getfirst(l))
data['click_rank'] = data['result_and_click'].apply(lambda l: getsecond(l))

# %%
data['query'] = data['query'].apply(lambda x: str(x)).apply(lambda x: x.strip().lstrip('[\"').rstrip('\"]'))

# %%
def remove_tail(url):
    if url[-1] == '/':
        return url[:-1]
    else:
        return url[:]

# %%
data['url'] = data['url'].apply(remove_tail)

# %%
data
# Out:
# Columns:
# 	﻿time	str
# 	user_id	str
# 	query	str
# 	result_click	str
# 	url	str
# 	result_and_click	list
# 	result_rank	int
# 	click_rank	int
#
# Rows: 500733
#
# Data:
# +----------+-------------------+--------------------+--------------+
# |  ﻿time   |      user_id      |       query        | result_click |
# +----------+-------------------+--------------------+--------------+
# | 00:00:00 |  3933365481995287 |    最佳受孕时间    |     6 3      |
# | 00:00:00 |  8248403977107859 |        pdf         |     1 1      |
# | 00:00:00 |  6551182914925117 |    尼康相机报价    |     6 4      |
# | 00:00:00 |  6478452674857782 |        1000        |     4 1      |
# | 00:00:00 | 23457845712802688 |        人妖        |     4 1      |
# | 00:00:00 |  4625224675315291 | 印尼排华是怎么回事 |     2 6      |
# | 00:00:00 |  5750662932822584 |   女士找鸭子经历   |     3 2      |
# | 00:00:01 |  8761939261737872 |   年轻人住房问题   |     11 7     |
# | 00:00:01 |  866575159856572  | 印尼排华是怎么回事 |     8 2      |
# | 00:00:01 |  5388089767668996 |   免费看三级图片   |     9 7      |
# +----------+-------------------+--------------------+--------------+
# +-------------------------------+------------------+-------------+------------+
# |              url              | result_and_click | result_rank | click_rank |
# +-------------------------------+------------------+-------------+------------+
# | ks.cn.yahoo.com/question/1... |      [6, 3]      |      6      |     3      |
# | download.it168.com/18/1805... |      [1, 1]      |      1      |     1      |
# | product.it168.com/list/b/0... |      [6, 4]      |      6      |     4      |
# |         www.1000dy.cn         |      [4, 1]      |      4      |     1      |
# | play.zol.com.cn/detail/165... |      [4, 1]      |      4      |     1      |
# | zhidao.baidu.com/question/... |      [2, 6]      |      2      |     6      |
# | zhangxiaoyu52.blog.sohu.co... |      [3, 2]      |      3      |     2      |
# | news.qq.com/a/20070810/002... |     [11, 7]      |      11     |     7      |
# | wenwen.soso.com/z/q3884674... |      [8, 2]      |      8      |     2      |
# | 226500.cn/bbs/dispbbs.asp?... |      [9, 7]      |      9      |     7      |
# +-------------------------------+------------------+-------------+------------+
# [500733 rows x 8 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data_words = []
data_poses = []
data_parsers = []
for query in data['query']:
    temp_words = segmentor.segment(query)
    temp_poses = postagger.postag(temp_words)
    temp_parsers = parser.parse(temp_words, temp_poses)
    words = ' '.join(temp_words)
    poses = ' '.join(temp_poses)
    parsers = ' '.join("%s" % (arc.relation) for arc in temp_parsers)
    data_words.append(words)
    data_poses.append(poses)
    data_parsers.append(parsers)

# %%
data['words'] = data_words
data['poses'] = data_poses
data['parsers'] = data_parsers

# %%
data.head()
# Out:
# Columns:
# 	﻿time	str
# 	user_id	str
# 	query	str
# 	result_click	str
# 	url	str
# 	result_and_click	list
# 	result_rank	int
# 	click_rank	int
# 	words	str
# 	poses	str
# 	parsers	str
#
# Rows: 10
#
# Data:
# +----------+-------------------+--------------------+--------------+
# |  ﻿time   |      user_id      |       query        | result_click |
# +----------+-------------------+--------------------+--------------+
# | 00:00:00 |  3933365481995287 |    最佳受孕时间    |     6 3      |
# | 00:00:00 |  8248403977107859 |        pdf         |     1 1      |
# | 00:00:00 |  6551182914925117 |    尼康相机报价    |     6 4      |
# | 00:00:00 |  6478452674857782 |        1000        |     4 1      |
# | 00:00:00 | 23457845712802688 |        人妖        |     4 1      |
# | 00:00:00 |  4625224675315291 | 印尼排华是怎么回事 |     2 6      |
# | 00:00:00 |  5750662932822584 |   女士找鸭子经历   |     3 2      |
# | 00:00:01 |  8761939261737872 |   年轻人住房问题   |     11 7     |
# | 00:00:01 |  866575159856572  | 印尼排华是怎么回事 |     8 2      |
# | 00:00:01 |  5388089767668996 |   免费看三级图片   |     9 7      |
# +----------+-------------------+--------------------+--------------+
# +-------------------------------+------------------+-------------+------------+
# |              url              | result_and_click | result_rank | click_rank |
# +-------------------------------+------------------+-------------+------------+
# | ks.cn.yahoo.com/question/1... |      [6, 3]      |      6      |     3      |
# | download.it168.com/18/1805... |      [1, 1]      |      1      |     1      |
# | product.it168.com/list/b/0... |      [6, 4]      |      6      |     4      |
# |         www.1000dy.cn         |      [4, 1]      |      4      |     1      |
# | play.zol.com.cn/detail/165... |      [4, 1]      |      4      |     1      |
# | zhidao.baidu.com/question/... |      [2, 6]      |      2      |     6      |
# | zhangxiaoyu52.blog.sohu.co... |      [3, 2]      |      3      |     2      |
# | news.qq.com/a/20070810/002... |     [11, 7]      |      11     |     7      |
# | wenwen.soso.com/z/q3884674... |      [8, 2]      |      8      |     2      |
# | 226500.cn/bbs/dispbbs.asp?... |      [9, 7]      |      9      |     7      |
# +-------------------------------+------------------+-------------+------------+
# +----------------------------+--------------+-------------------------+
# |           words            |    poses     |         parsers         |
# +----------------------------+--------------+-------------------------+
# |       最佳 受孕 时间       |    z v n     |       ATT ATT HED       |
# |            pdf             |      ws      |           HED           |
# |       尼康 相机 报价       |    nz n v    |       ATT ATT HED       |
# |            1000            |      m       |           HED           |
# |            人妖            |      n       |           HED           |
# | 印尼 排华 是 怎么 回 事... | ns v v r q n | ATT SBV HED ATT ATT VOB |
# |     女士 找 鸭子 经历      |   n v n n    |     SBV HED VOB VOB     |
# |      年轻人 住房 问题      |    n n n     |       ATT ATT HED       |
# | 印尼 排华 是 怎么 回 事... | ns v v r q n | ATT SBV HED ATT ATT VOB |
# |     免费 看 三级 图片      |   v v b n    |     ADV HED ATT VOB     |
# +----------------------------+--------------+-------------------------+
# [10 rows x 11 columns]

# %%
data['len_words'] = data['query'].apply(lambda x: len(x.decode('utf-8')))

# %%
data['len_seg'] = data['words'].apply(lambda x: len(re.split(r'\s+',x)))

# %%
data['len_parser'] = data['parsers'].apply(lambda x: len(re.split(r'\s+',x)))

# %%
data.head()
# Out:
# Columns:
# 	﻿time	str
# 	user_id	str
# 	query	str
# 	result_click	str
# 	url	str
# 	result_and_click	list
# 	result_rank	int
# 	click_rank	int
# 	words	str
# 	poses	str
# 	parsers	str
# 	len_words	int
# 	len_seg	int
# 	len_parser	int
#
# Rows: 10
#
# Data:
# +----------+-------------------+--------------------+--------------+
# |  ﻿time   |      user_id      |       query        | result_click |
# +----------+-------------------+--------------------+--------------+
# | 00:00:00 |  3933365481995287 |    最佳受孕时间    |     6 3      |
# | 00:00:00 |  8248403977107859 |        pdf         |     1 1      |
# | 00:00:00 |  6551182914925117 |    尼康相机报价    |     6 4      |
# | 00:00:00 |  6478452674857782 |        1000        |     4 1      |
# | 00:00:00 | 23457845712802688 |        人妖        |     4 1      |
# | 00:00:00 |  4625224675315291 | 印尼排华是怎么回事 |     2 6      |
# | 00:00:00 |  5750662932822584 |   女士找鸭子经历   |     3 2      |
# | 00:00:01 |  8761939261737872 |   年轻人住房问题   |     11 7     |
# | 00:00:01 |  866575159856572  | 印尼排华是怎么回事 |     8 2      |
# | 00:00:01 |  5388089767668996 |   免费看三级图片   |     9 7      |
# +----------+-------------------+--------------------+--------------+
# +-------------------------------+------------------+-------------+------------+
# |              url              | result_and_click | result_rank | click_rank |
# +-------------------------------+------------------+-------------+------------+
# | ks.cn.yahoo.com/question/1... |      [6, 3]      |      6      |     3      |
# | download.it168.com/18/1805... |      [1, 1]      |      1      |     1      |
# | product.it168.com/list/b/0... |      [6, 4]      |      6      |     4      |
# |         www.1000dy.cn         |      [4, 1]      |      4      |     1      |
# | play.zol.com.cn/detail/165... |      [4, 1]      |      4      |     1      |
# | zhidao.baidu.com/question/... |      [2, 6]      |      2      |     6      |
# | zhangxiaoyu52.blog.sohu.co... |      [3, 2]      |      3      |     2      |
# | news.qq.com/a/20070810/002... |     [11, 7]      |      11     |     7      |
# | wenwen.soso.com/z/q3884674... |      [8, 2]      |      8      |     2      |
# | 226500.cn/bbs/dispbbs.asp?... |      [9, 7]      |      9      |     7      |
# +-------------------------------+------------------+-------------+------------+
# +----------------------------+--------------+-------------------------+-----------+
# |           words            |    poses     |         parsers         | len_words |
# +----------------------------+--------------+-------------------------+-----------+
# |       最佳 受孕 时间       |    z v n     |       ATT ATT HED       |     6     |
# |            pdf             |      ws      |           HED           |     3     |
# |       尼康 相机 报价       |    nz n v    |       ATT ATT HED       |     6     |
# |            1000            |      m       |           HED           |     4     |
# |            人妖            |      n       |           HED           |     2     |
# | 印尼 排华 是 怎么 回 事... | ns v v r q n | ATT SBV HED ATT ATT VOB |     9     |
# |     女士 找 鸭子 经历      |   n v n n    |     SBV HED VOB VOB     |     7     |
# |      年轻人 住房 问题      |    n n n     |       ATT ATT HED       |     7     |
# | 印尼 排华 是 怎么 回 事... | ns v v r q n | ATT SBV HED ATT ATT VOB |     9     |
# |     免费 看 三级 图片      |   v v b n    |     ADV HED ATT VOB     |     7     |
# +----------------------------+--------------+-------------------------+-----------+
# +---------+------------+
# | len_seg | len_parser |
# +---------+------------+
# |    3    |     3      |
# |    1    |     1      |
# |    3    |     3      |
# |    1    |     1      |
# |    1    |     1      |
# |    6    |     6      |
# |    4    |     4      |
# |    3    |     3      |
# |    6    |     6      |
# |    4    |     4      |
# +---------+------------+
# [10 rows x 14 columns]

# %%
data.save('Sogou50W_ltp.csv')
